# %% [markdown]
# # Basic Statistics
# # To perform descriptive analytics, visualize data distributions, and preprocess the dataset for further analysis.
# ## Q.1 Descriptive Analytics for Numerical Columns
# ### To compute and analyse basic statistical measures for numerical columns in the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("https://raw.githubusercontent.com/SayaliD6/Datasets_used_in_assignments/main/BS1_sales_data_with_discounts.csv")

# %%
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
numerical_columns = df.select_dtypes(include=['int', 'float']).columns
for column_name in numerical_columns:
    # Calculate mean
    mean_value = df[column_name].mean()

    # Calculate mode (mode returns multiple values if there are multiple modes)
    mode_values = df[column_name].mode()

    # Calculate median
    median_value = df[column_name].median()

    print("Column:", column_name)
    print("Mean:",mean_value)
    print("Mode:", mode_values.tolist())  # Convert mode values to list for printing
    print("Median:", median_value)
    print("\n")
# Out:
# Column: Volume
# Mean: 5.066666666666666
# Mode: [3]
# Median: 4.0
#
#
# Column: Avg Price
# Mean: 10453.433333333332
# Mode: [400, 450, 500, 1300, 8100]
# Median: 1450.0
#
#
# Column: Total Sales Value
# Mean: 33812.83555555555
# Mode: [24300]
# Median: 5700.0
#
#
# Column: Discount Rate (%)
# Mean: 15.155241895330914
# ...

# %% [markdown]
# ## Q.2 Data Visualization
# ### To visualize the distribution and relationship of numerical and categorical variables in the dataset.

# %%
numerical_columns = df.select_dtypes(include=['int', 'float']).columns

# Plot histograms for each numerical column
for column in numerical_columns:
    plt.hist(df[column], bins=10, alpha=0.5, label=column)
    plt.title('Histograms of Numerical Columns')
    # plt.xlabel('Value')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
for column in numerical_columns:
    plt.figure()
    plt.boxplot(df[column])
    plt.xlabel(column)
    plt.ylabel('Value')
    plt.title('Box plot of ' + column)
    plt.show()

# %%
categorical_columns = df[['Brand','BU']]

for column in categorical_columns:
    category_counts = df[column].value_counts()

    plt.figure(figsize=(8, 6))
    category_counts.plot(kind='bar', color='skyblue')
    plt.title('Frequency of ' + column)
    plt.xlabel('Categories')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# # Standardization of Numerical Variables
# ## Q3 To scale numerical variables for uniformity, improving the dataset’s suitability for analytical models.

# %%
df[numerical_columns]
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# ...

# %%
# Standardize numerical columns
for column in numerical_columns:
    mu = df[column].mean()
    sigma = df[column].std()
    df[column] = (df[column] - mu) / sigma

# %%
df[numerical_columns]
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.347417   0.091072           2.922469          -0.829365
# 1    1.165831  -0.019548           1.329516          -0.851714
# 2    0.456880   0.312312           1.561038          -1.350129
# 3    0.220563   0.533552           1.717365          -1.947555
# 4   -0.488389  -0.130168          -0.188242           0.672990
# ..        ...        ...                ...                ...
# 445 -0.724706  -0.506277          -0.617647           0.075924
# 446  0.220563  -0.434374          -0.360400           0.450596
# 447 -0.724706  -0.489684          -0.605774           0.902788
# 448 -0.488389  -0.473091          -0.556303           0.388042
# 449 -0.961023  -0.406719          -0.607753           0.042188
#
#      Discount Amount  Net Sales Value
# 0           3.948422         2.801638
# 1           1.846958         1.269613
# 2           1.621190         1.543957
# 3           1.112568         1.763847
# ...

# %% [markdown]
# # Conversion of Categorical Data into Dummy Variables
# ### Q.4 To transform categorical variables into a format that can be provided to ML algorithms.

# %%
df.drop(columns=['Date','Day','City','SKU','Model','Brand'], inplace=True)
categorical_columns = df.select_dtypes(include=['object']).columns
df= pd.get_dummies(df, columns=categorical_columns)
print(df.head())
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0  2.347417   0.091072           2.922469          -0.829365         3.948422
# 1  1.165831  -0.019548           1.329516          -0.851714         1.846958
# 2  0.456880   0.312312           1.561038          -1.350129         1.621190
# 3  0.220563   0.533552           1.717365          -1.947555         1.112568
# 4 -0.488389  -0.130168          -0.188242           0.672990         0.227598
#
#    Net Sales Value  BU_FMCG  BU_Lifestyle  BU_Mobiles
# 0         2.801638        0             0           1
# 1         1.269613        0             0           1
# 2         1.543957        0             0           1
# 3         1.763847        0             0           1
# 4        -0.227342        0             0           1
